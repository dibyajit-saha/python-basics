# %% [markdown]
# ### 1. 1.	Store a message in a variable and print it in:
# ###o	Uppercase
# ###o	Lowercase
# ###o	Title case (first letter capitalized)

# %%
d = "dibYAJit"

print (d.upper())
print (d.lower())
print (d.capitalize())
# Out:
# DIBYAJIT
# dibyajit
# Dibyajit

# %% [markdown]
# ### 2.Store a person’s name in a variable. Print a message such as:"Hello Alice, welcome to Python programming!"

# %%
a = 'Alice'

print ("Hello ",a,", welcome to Python Programming!")
# Out:
# Hello  Alice , welcome to Python Programming!

# %% [markdown]
# ### 3.	Store a word in a variable and print: o	The first character o	The last character o	The length of the word

# %%
p = "python"

print ("The first character is ", p[0])
print ("The last character is ", p[-1])
print ("The length of the word is ", len(p))
# Out:
# The first character is  p
# The last character is  n
# The length of the word is  6

# %% [markdown]
# ### 4.	Find your favorite quote and print it with quotation marks. Example:"Mahatma Gandhi once said, “Be the change that you wish to see in the world.”

# %%
person =  "Netaji Subhash"
quote = "Give me blood, I shall give you freedom"

print (f'{person} once said,"{quote}".')
# Out:
# Netaji Subhash once said,"Give me blood, I shall give you freedom".

# %% [markdown]
# ### 5.	Store two strings in different variables and print them joined with a space in between.

# %%
a = 'Dibyajit'
b = 'Saha'

print (a + " " + b)
# Out:
# Dibyajit Saha

# %% [markdown]
# ### 6.	Store a sentence in a variable and check if it contains the word "Python". Print True or False.

# %%
a = input('Entre a sentence:')
print ("python" in a.lower())
# Out:
# Entre a sentence: I love Python
# True

# %% [markdown]
# ### 7.	Ask the user to enter their name and print: "Hello <name>, how are you today?"

# %%
a = input ("Enter your name: ")

print (f'Hello {a},"How are you today?"')
# Out:
# Enter your name:  Dibyajit
# Hello Dibyajit,"How are you today?"

# %% [markdown]
# ### 8.	Ask the user to enter their age and print: "You are <age> years old."

# %%
age = int(input("Enter your age: "))
print ("You are",age,"years old")
# Out:
# Enter your age:  26
# You are 26 years old

# %% [markdown]
# ### 9.	Ask the user for two numbers and print their: o	Sum o	Difference o	Product o	Quotient

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print ("The sum is ", a+b)
print ("The difference is ", a-b)
print("The product is ", a*b)
print ("The quotient is ", a/b)
# Out:
# Enter first number:  25
# Enter second number:  12
# The sum is  37
# The difference is  13
# The product is  300
# The quotient is  2.0833333333333335

# %% [markdown]
# ### 10.	Ask the user to enter a sentence and print it reversed.

# %%
a = input("Enter a sentence: ")
b = a.split()

print (" ".join(b[::-1]))
# Out:
# Enter a sentence:  I love cricket
# cricket love I

# %% [markdown]
# ### 11.	Ask the user for their favorite color and print:"Wow! <color> is a beautiful color!"

# %%
c = input ("Enter your favourate colour: ")
print (f'Wow! {c} is a beautiful colour!')
# Out:
# Enter your favourate colour:  Blue
# Wow! Blue is a beautiful colour!

# %% [markdown]
# ### 12.	Ask the user to enter a number and print True if it is greater than 50, otherwise print False.

# %%
x = int (input ("Enter a number: "))

print (x>50)
# Out:
# Enter a number:  25
# False

# %% [markdown]
# ### 13.	Ask the user to enter a number and print True if it is even, otherwise print False.

# %%
y = int (input ("Enter a number: "))
print (y%2 == 0)
# Out:
# Enter a number:  2
# True

# %% [markdown]
# ### 14.	Ask the user to enter their age and check if they are eligible to vote (age ≥ 18). Print True or False.

# %%
z = int (input ("Enter your age : "))
print (z>=18)
# Out:
# Enter your age :  12
# False

# %% [markdown]
# ### 15.	Ask the user to enter two numbers and print True if the first number is greater than the second, else print False.

# %%
g = int (input ("Enter first number: "))
h = int (input ("Enter second number: "))
print (g>h)
# Out:
# Enter first number:  34
# Enter second number:  22
# True

# %% [markdown]
# ### 16.	Ask the user to enter a word and check if its length is more than 5 characters. Print True or False.

# %%
q = input  ("Entre a word: ")
print ( len(q) > 5)
# Out:
# Entre a word:  dibyajit
# True

# %% [markdown]
# ### 17.	Write a program that asks the user to enter a password.Your program should check and print: - True if the password length is at least 8 characters and contains the word "@" or "#". - False otherwise.

# %%
w = input ("Enter the password: ")
if len(w)>= 8 and ("@" or "#" in w):
    print (True)
else:
    print (False)
# Out:
# Enter the password:  Dibyajit
# True
